# %% [markdown]
# Deep Learning
# =============
#
# Assignment 4
# ------------
#
# Previously in `2_fullyconnected.ipynb` and `3_regularization.ipynb`, we trained fully connected networks to classify [notMNIST](http://yaroslavvb.blogspot.com/2011/09/notmnist-dataset.html) characters.
#
# The goal of this assignment is make the neural network convolutional.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import numpy as np
import tensorflow as tf
from six.moves import cPickle as pickle
from six.moves import range

# %%
pickle_file = 'notMNIST.pickle'

with open(pickle_file, 'rb') as f:
  save = pickle.load(f)
  train_dataset = save['train_dataset']
  train_labels = save['train_labels']
  valid_dataset = save['valid_dataset']
  valid_labels = save['valid_labels']
  test_dataset = save['test_dataset']
  test_labels = save['test_labels']
  del save  # hint to help gc free up memory
  print('Training set', train_dataset.shape, train_labels.shape)
  print('Validation set', valid_dataset.shape, valid_labels.shape)
  print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28) (200000,)
# Validation set (10000, 28, 28) (10000,)
# Test set (10000, 28, 28) (10000,)

# %% [markdown]
# Reformat into a TensorFlow-friendly shape:
# - convolutions need the image data formatted as a cube (width by height by #channels)
# - labels as float 1-hot encodings.

# %%
image_size = 28
num_labels = 10
num_channels = 1 # grayscale

import numpy as np

def reformat(dataset, labels):
  dataset = dataset.reshape(
    (-1, image_size, image_size, num_channels)).astype(np.float32)
  labels = (np.arange(num_labels) == labels[:,None]).astype(np.float32)
  return dataset, labels
train_dataset, train_labels = reformat(train_dataset, train_labels)
valid_dataset, valid_labels = reformat(valid_dataset, valid_labels)
test_dataset, test_labels = reformat(test_dataset, test_labels)
print('Training set', train_dataset.shape, train_labels.shape)
print('Validation set', valid_dataset.shape, valid_labels.shape)
print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28, 1) (200000, 10)
# Validation set (10000, 28, 28, 1) (10000, 10)
# Test set (10000, 28, 28, 1) (10000, 10)

# %%
def accuracy(predictions, labels):
  return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1))
          / predictions.shape[0])

# %% [markdown]
# Let's build a small network with two convolutional layers, followed by one fully connected layer. Convolutional networks are more expensive computationally, so we'll limit its depth and number of fully connected nodes.

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    conv = tf.nn.conv2d(hidden, layer2_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    shape = hidden.get_shape().as_list()
    reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 3.016683
# Minibatch accuracy: 12.5%
# Validation accuracy: 10.0%
# Minibatch loss at step 50: 1.435394
# Minibatch accuracy: 56.2%
# Validation accuracy: 54.4%
# Minibatch loss at step 100: 0.970012
# Minibatch accuracy: 56.2%
# Validation accuracy: 72.8%
# Minibatch loss at step 150: 0.708194
# Minibatch accuracy: 75.0%
# Validation accuracy: 74.2%
# Minibatch loss at step 200: 0.945169
# Minibatch accuracy: 87.5%
# Validation accuracy: 75.7%
# Minibatch loss at step 250: 1.373123
# Minibatch accuracy: 62.5%
# Validation accuracy: 77.1%
# Minibatch loss at step 300: 0.516424
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.4%
# Minibatch loss at step 350: 0.717261
# Minibatch accuracy: 75.0%
# Validation accuracy: 77.2%
# Minibatch loss at step 400: 0.596097
# Minibatch accuracy: 87.5%
# Validation accuracy: 78.8%
# Minibatch loss at step 450: 0.498701
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.0%
# Minibatch loss at step 500: 0.434097
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.6%
# Minibatch loss at step 550: 0.374809
# Minibatch accuracy: 93.8%
# Validation accuracy: 81.0%
# Minibatch loss at step 600: 0.494656
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.6%
# Minibatch loss at step 650: 0.633281
# Minibatch accuracy: 75.0%
# Validation accuracy: 80.8%
# Minibatch loss at step 700: 0.589082
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.9%
# Minibatch loss at step 750: 0.565055
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.9%
# Minibatch loss at step 800: 0.569809
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.9%
# Minibatch loss at step 850: 0.554509
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.9%
# Minibatch loss at step 900: 0.581024
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.1%
# Minibatch loss at step 950: 0.957533
# Minibatch accuracy: 68.8%
# Validation accuracy: 82.0%
# Minibatch loss at step 1000: 0.537634
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.5%
# Test accuracy: 89.5%

# %% [markdown]
# ---
# Problem 1
# ---------
#
# The convolutional model above uses convolutions with stride 2 to reduce the dimensionality. Replace the strides by a max pooling operation (`nn.max_pool()`) of stride 2 and kernel size 2.
#
# ---

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    pool = tf.nn.max_pool(hidden, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')
    conv = tf.nn.conv2d(pool, layer2_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    pool = tf.nn.max_pool(hidden, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')
    shape = pool.get_shape().as_list()
    print (shape)
    reshape = tf.reshape(pool, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(logits = logits, labels = tf_train_labels))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))
# Out:
# [16, 7, 7, 16]
# [10000, 7, 7, 16]
# [10000, 7, 7, 16]

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 2.951376
# Minibatch accuracy: 18.8%
# Validation accuracy: 12.3%
# Minibatch loss at step 50: 1.659227
# Minibatch accuracy: 31.2%
# Validation accuracy: 40.2%
# Minibatch loss at step 100: 1.114569
# Minibatch accuracy: 62.5%
# Validation accuracy: 64.5%
# Minibatch loss at step 150: 0.625695
# Minibatch accuracy: 81.2%
# Validation accuracy: 68.1%
# Minibatch loss at step 200: 0.945929
# Minibatch accuracy: 75.0%
# Validation accuracy: 74.6%
# Minibatch loss at step 250: 1.628532
# Minibatch accuracy: 50.0%
# Validation accuracy: 77.3%
# Minibatch loss at step 300: 0.653221
# Minibatch accuracy: 75.0%
# Validation accuracy: 79.4%
# Minibatch loss at step 350: 0.539731
# Minibatch accuracy: 75.0%
# Validation accuracy: 79.6%
# Minibatch loss at step 400: 0.734910
# Minibatch accuracy: 75.0%
# Validation accuracy: 80.5%
# Minibatch loss at step 450: 0.500589
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.6%
# Minibatch loss at step 500: 0.288189
# Minibatch accuracy: 93.8%
# Validation accuracy: 80.1%
# Minibatch loss at step 550: 0.415834
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.1%
# Minibatch loss at step 600: 0.494932
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.9%
# Minibatch loss at step 650: 0.478977
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.8%
# Minibatch loss at step 700: 0.470370
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.0%
# Minibatch loss at step 750: 0.478584
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.5%
# Minibatch loss at step 800: 0.602744
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.4%
# Minibatch loss at step 850: 0.525836
# Minibatch accuracy: 75.0%
# Validation accuracy: 83.7%
# Minibatch loss at step 900: 0.456747
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.7%
# Minibatch loss at step 950: 0.931953
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.5%
# Minibatch loss at step 1000: 0.240525
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.0%
# Test accuracy: 90.3%

# %% [markdown]
# ---
# Problem 2
# ---------
#
# Try to get the best performance you can using a convolutional net. Look for example at the classic [LeNet5](http://yann.lecun.com/exdb/lenet/) architecture, adding Dropout, and/or adding learning rate decay.
#
# ---

# %%
batch_size = 128
patch_size = 5
depth = 16
num_hidden = 64

num_steps = 0 # Needed for learning rate decay

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data, train=True):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    pool = tf.nn.max_pool(hidden, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')
    conv = tf.nn.conv2d(pool, layer2_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    pool = tf.nn.max_pool(hidden, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')
    shape = pool.get_shape().as_list()
    print (shape)
    reshape = tf.reshape(pool, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    if (train):
        hidden = tf.nn.dropout(hidden, 0.5)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(logits = logits, labels = tf_train_labels))
    
  # Optimizer.
  starting_learning_rate = 0.05
  learning_rate = tf.train.exponential_decay(starting_learning_rate, num_steps, 2001, 0.95, staircase=True)
  optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset, False))
  test_prediction = tf.nn.softmax(model(tf_test_dataset, False))
# Out:
# [128, 7, 7, 16]
# [10000, 7, 7, 16]
# [10000, 7, 7, 16]

# %%
num_steps = 2001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# WARNING:tensorflow:From <ipython-input-10-3f9219ac6509>:4: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Initialized
# Minibatch loss at step 0: 4.483618
# Minibatch accuracy: 3.9%
# Validation accuracy: 10.0%
# Minibatch loss at step 50: 1.747051
# Minibatch accuracy: 39.1%
# Validation accuracy: 60.1%
# Minibatch loss at step 100: 1.373696
# Minibatch accuracy: 60.2%
# Validation accuracy: 73.5%
# Minibatch loss at step 150: 1.151371
# Minibatch accuracy: 58.6%
# Validation accuracy: 77.3%
# Minibatch loss at step 200: 1.022781
# Minibatch accuracy: 70.3%
# Validation accuracy: 78.7%
# Minibatch loss at step 250: 0.890336
# Minibatch accuracy: 72.7%
# Validation accuracy: 79.0%
# Minibatch loss at step 300: 0.781830
# Minibatch accuracy: 76.6%
# Validation accuracy: 80.0%
# Minibatch loss at step 350: 0.848996
# Minibatch accuracy: 73.4%
# Validation accuracy: 80.6%
# Minibatch loss at step 400: 0.712022
# Minibatch accuracy: 78.9%
# Validation accuracy: 80.8%
# Minibatch loss at step 450: 0.731790
# Minibatch accuracy: 80.5%
# Validation accuracy: 81.0%
# Minibatch loss at step 500: 0.584600
# Minibatch accuracy: 83.6%
# Validation accuracy: 81.9%
# Minibatch loss at step 550: 0.673117
# Minibatch accuracy: 76.6%
# Validation accuracy: 82.0%
# Minibatch loss at step 600: 0.691029
# Minibatch accuracy: 78.1%
# Validation accuracy: 82.5%
# Minibatch loss at step 650: 0.804657
# Minibatch accuracy: 78.1%
# Validation accuracy: 82.4%
# Minibatch loss at step 700: 0.591410
# Minibatch accuracy: 83.6%
# Validation accuracy: 82.7%
# Minibatch loss at step 750: 0.791849
# Minibatch accuracy: 79.7%
# Validation accuracy: 83.2%
# Minibatch loss at step 800: 0.809525
# Minibatch accuracy: 72.7%
# Validation accuracy: 82.8%
# Minibatch loss at step 850: 0.437961
# Minibatch accuracy: 85.9%
# Validation accuracy: 83.6%
# Minibatch loss at step 900: 0.576754
# Minibatch accuracy: 85.2%
# Validation accuracy: 83.8%
# Minibatch loss at step 950: 0.667750
# Minibatch accuracy: 78.1%
# Validation accuracy: 83.6%
# Minibatch loss at step 1000: 0.916438
# Minibatch accuracy: 75.8%
# Validation accuracy: 84.1%
# Minibatch loss at step 1050: 0.582300
# Minibatch accuracy: 82.0%
# Validation accuracy: 84.1%
# Minibatch loss at step 1100: 0.537994
# Minibatch accuracy: 83.6%
# Validation accuracy: 84.4%
# Minibatch loss at step 1150: 0.601334
# Minibatch accuracy: 80.5%
# Validation accuracy: 84.1%
# Minibatch loss at step 1200: 0.701984
# Minibatch accuracy: 79.7%
# Validation accuracy: 84.5%
# Minibatch loss at step 1250: 0.641647
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.8%
# Minibatch loss at step 1300: 0.649509
# Minibatch accuracy: 82.0%
# Validation accuracy: 85.0%
# Minibatch loss at step 1350: 0.586130
# Minibatch accuracy: 79.7%
# Validation accuracy: 84.9%
# Minibatch loss at step 1400: 0.668283
# Minibatch accuracy: 75.8%
# Validation accuracy: 85.0%
# Minibatch loss at step 1450: 0.568758
# Minibatch accuracy: 85.2%
# Validation accuracy: 85.3%
# Minibatch loss at step 1500: 0.509387
# Minibatch accuracy: 86.7%
# Validation accuracy: 85.3%
# Minibatch loss at step 1550: 0.587886
# Minibatch accuracy: 79.7%
# Validation accuracy: 85.5%
# Minibatch loss at step 1600: 0.582558
# Minibatch accuracy: 82.8%
# Validation accuracy: 85.3%
# Minibatch loss at step 1650: 0.573119
# Minibatch accuracy: 82.0%
# Validation accuracy: 85.5%
# Minibatch loss at step 1700: 0.596804
# Minibatch accuracy: 82.0%
# Validation accuracy: 85.4%
# Minibatch loss at step 1750: 0.559824
# Minibatch accuracy: 82.0%
# Validation accuracy: 85.7%
# Minibatch loss at step 1800: 0.719298
# Minibatch accuracy: 80.5%
# Validation accuracy: 85.6%
# Minibatch loss at step 1850: 0.504922
# Minibatch accuracy: 85.9%
# Validation accuracy: 85.8%
# Minibatch loss at step 1900: 0.611327
# Minibatch accuracy: 78.1%
# Validation accuracy: 85.5%
# Minibatch loss at step 1950: 0.408000
# Minibatch accuracy: 85.9%
# Validation accuracy: 85.8%
# Minibatch loss at step 2000: 0.394664
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.9%
# Test accuracy: 92.3%
